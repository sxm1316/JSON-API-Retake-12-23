# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress
from pprint import pprint
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %%
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it'sbeing processed (with the city number and city name).
MaxtempF = []
humidityperc = []
cloudiness = []
windmph = []
mod_cities = []
mod_lat = []
mod_lngs = []
country = []

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
for i, city in enumerate(cities):
    api = url + "&q=" + city.replace(" ","+")
    response = requests.get(api)
    weather_data = response.json()
    print("Processing Record " + str(i+1) + " of set 1 |" + str(city))
    
    try:
        mod_lat.append(weather_data['coord']['lat'])
        mod_lngs.append(weather_data['coord']['lon'])
        country.append(weather_data['sys']['country'])
        mod_cities.append(weather_data['name'])
        MaxtempF.append(weather_data["main"]["temp_max"])
        humidityperc.append(weather_data['main']['humidity'])
        cloudiness.append(weather_data['visibility'])
        windmph.append(weather_data['wind']['speed'])
    except: 
        print(city + " not found in API response.")
    i += 1
# Out:
# Processing Record 1 of set 1 |busselton
# Processing Record 2 of set 1 |port lincoln
# Processing Record 3 of set 1 |sorong
# Processing Record 4 of set 1 |san quintin
# Processing Record 5 of set 1 |jamestown
# Processing Record 6 of set 1 |vila velha
# Processing Record 7 of set 1 |los llanos de aridane
# Processing Record 8 of set 1 |ahuimanu
# Processing Record 9 of set 1 |touros
# Processing Record 10 of set 1 |rikitea
# Processing Record 11 of set 1 |inhambane
# Processing Record 12 of set 1 |mirnyy
# Processing Record 13 of set 1 |lavrentiya
# Processing Record 14 of set 1 |bambous virieux
# Processing Record 15 of set 1 |kapaa
# Processing Record 16 of set 1 |albany
# Processing Record 17 of set 1 |vagur
# Processing Record 18 of set 1 |dalby
# Processing Record 19 of set 1 |nanuque
# Processing Record 20 of set 1 |tiksi
# Processing Record 21 of set 1 |luderitz
# Processing Record 22 of set 1 |nanortalik
# Processing Record 23 of set 1 |kahului
# Processing Record 24 of set 1 |port alfred
# Processing Record 25 of set 1 |east london
# Processing Record 26 of set 1 |hermanus
# Processing Record 27 of set 1 |kaputa
# Processing Record 28 of set 1 |samusu
# samusu not found in API response.
# Processing Record 29 of set 1 |bluff
# Processing Record 30 of set 1 |hamilton
# Processing Record 31 of set 1 |guerrero
# Processing Record 32 of set 1 |najran
# Processing Record 33 of set 1 |tasiilaq
# Processing Record 34 of set 1 |punta arenas
# Processing Record 35 of set 1 |champerico
# Processing Record 36 of set 1 |ugoofaaru
# Processing Record 37 of set 1 |shalya
# Processing Record 38 of set 1 |hualmay
# Processing Record 39 of set 1 |tuktoyaktuk
# Processing Record 40 of set 1 |bredasdorp
# Processing Record 41 of set 1 |vostok
# Processing Record 42 of set 1 |ushuaia
# Processing Record 43 of set 1 |quelimane
# Processing Record 44 of set 1 |gorontalo
# Processing Record 45 of set 1 |makubetsu
# Processing Record 46 of set 1 |pasuquin
# Processing Record 47 of set 1 |yellowknife
# Processing Record 48 of set 1 |attawapiskat
# attawapiskat not found in API response.
# Processing Record 49 of set 1 |klaksvik
# Processing Record 50 of set 1 |aasiaat
# Processing Record 51 of set 1 |okhotsk
# Processing Record 52 of set 1 |murgab
# Processing Record 53 of set 1 |hobart
# Processing Record 54 of set 1 |chokurdakh
# Processing Record 55 of set 1 |lompoc
# Processing Record 56 of set 1 |aklavik
# Processing Record 57 of set 1 |vaini
# Processing Record 58 of set 1 |geraldton
# Processing Record 59 of set 1 |atuona
# Processing Record 60 of set 1 |nizhneyansk
# nizhneyansk not found in API response.
# Processing Record 61 of set 1 |mataura
# Processing Record 62 of set 1 |cap malheureux
# Processing Record 63 of set 1 |cape town
# Processing Record 64 of set 1 |mar del plata
# Processing Record 65 of set 1 |kenai
# Processing Record 66 of set 1 |ribeira grande
# Processing Record 67 of set 1 |qaanaaq
# Processing Record 68 of set 1 |burnie
# Processing Record 69 of set 1 |saleaula
# saleaula not found in API response.
# Processing Record 70 of set 1 |castro
# Processing Record 71 of set 1 |taolanaro
# taolanaro not found in API response.
# Processing Record 72 of set 1 |svetlyy
# Processing Record 73 of set 1 |illoqqortoormiut
# illoqqortoormiut not found in API response.
# Processing Record 74 of set 1 |constitucion
# Processing Record 75 of set 1 |glendive
# Processing Record 76 of set 1 |phalaborwa
# Processing Record 77 of set 1 |hithadhoo
# Processing Record 78 of set 1 |nikolskoye
# Processing Record 79 of set 1 |esperance
# Processing Record 80 of set 1 |ancud
# Processing Record 81 of set 1 |khatanga
# Processing Record 82 of set 1 |severo-kurilsk
# Processing Record 83 of set 1 |pampa
# Processing Record 84 of set 1 |seoul
# Processing Record 85 of set 1 |hilo
# Processing Record 86 of set 1 |port elizabeth
# Processing Record 87 of set 1 |georgetown
# Processing Record 88 of set 1 |palabuhanratu
# palabuhanratu not found in API response.
# Processing Record 89 of set 1 |kentau
# Processing Record 90 of set 1 |cockburn harbour
# cockburn harbour not found in API response.
# Processing Record 91 of set 1 |yaroslavskaya
# Processing Record 92 of set 1 |villarrobledo
# Processing Record 93 of set 1 |batemans bay
# Processing Record 94 of set 1 |butaritari
# Processing Record 95 of set 1 |marcona
# marcona not found in API response.
# Processing Record 96 of set 1 |chuy
# Processing Record 97 of set 1 |necochea
# Processing Record 98 of set 1 |college
# Processing Record 99 of set 1 |sobolevo
# Processing Record 100 of set 1 |almaznyy
# Processing Record 101 of set 1 |anadyr
# Processing Record 102 of set 1 |san cristobal
# Processing Record 103 of set 1 |salalah
# Processing Record 104 of set 1 |bouna
# Processing Record 105 of set 1 |huntington
# Processing Record 106 of set 1 |samarai
# Processing Record 107 of set 1 |hasaki
# Processing Record 108 of set 1 |saquarema
# Processing Record 109 of set 1 |port blair
# Processing Record 110 of set 1 |tomatlan
# Processing Record 111 of set 1 |chihuahua
# Processing Record 112 of set 1 |alofi
# Processing Record 113 of set 1 |puerto ayora
# Processing Record 114 of set 1 |ulladulla
# Processing Record 115 of set 1 |umzimvubu
# umzimvubu not found in API response.
# Processing Record 116 of set 1 |baracska
# Processing Record 117 of set 1 |road town
# Processing Record 118 of set 1 |codrington
# Processing Record 119 of set 1 |tilichiki
# Processing Record 120 of set 1 |gallup
# Processing Record 121 of set 1 |nouadhibou
# Processing Record 122 of set 1 |frederikshavn
# Processing Record 123 of set 1 |arraial do cabo
# Processing Record 124 of set 1 |grootfontein
# Processing Record 125 of set 1 |argalasti
# Processing Record 126 of set 1 |songea
# Processing Record 127 of set 1 |santa maria
# Processing Record 128 of set 1 |tefe
# Processing Record 129 of set 1 |vangaindrano
# Processing Record 130 of set 1 |vysokogornyy
# Processing Record 131 of set 1 |sirpur
# Processing Record 132 of set 1 |new norfolk
# Processing Record 133 of set 1 |sept-iles
# Processing Record 134 of set 1 |dourdan
# Processing Record 135 of set 1 |corinto
# Processing Record 136 of set 1 |lorengau
# Processing Record 137 of set 1 |longlac
# longlac not found in API response.
# Processing Record 138 of set 1 |isangel
# Processing Record 139 of set 1 |aflu
# aflu not found in API response.
# Processing Record 140 of set 1 |narsaq
# Processing Record 141 of set 1 |voi
# Processing Record 142 of set 1 |shingu
# Processing Record 143 of set 1 |faanui
# Processing Record 144 of set 1 |avarua
# Processing Record 145 of set 1 |phek
# Processing Record 146 of set 1 |louisbourg
# louisbourg not found in API response.
# Processing Record 147 of set 1 |saint-philippe
# Processing Record 148 of set 1 |santa cruz cabralia
# Processing Record 149 of set 1 |krasnouralsk
# Processing Record 150 of set 1 |cherskiy
# Processing Record 151 of set 1 |inderborskiy
# inderborskiy not found in API response.
# Processing Record 152 of set 1 |mahebourg
# Processing Record 153 of set 1 |katsuura
# Processing Record 154 of set 1 |bosaso
# Processing Record 155 of set 1 |robertsport
# Processing Record 156 of set 1 |dwarka
# Processing Record 157 of set 1 |barrow
# Processing Record 158 of set 1 |airai
# Processing Record 159 of set 1 |seymchan
# Processing Record 160 of set 1 |ostrovnoy
# Processing Record 161 of set 1 |neryungri
# Processing Record 162 of set 1 |ahipara
# Processing Record 163 of set 1 |souillac
# Processing Record 164 of set 1 |upernavik
# Processing Record 165 of set 1 |vao
# Processing Record 166 of set 1 |olga
# Processing Record 167 of set 1 |portland
# Processing Record 168 of set 1 |mbini
# Processing Record 169 of set 1 |oksfjord
# Processing Record 170 of set 1 |kaitangata
# Processing Record 171 of set 1 |ayios kirikos
# ayios kirikos not found in API response.
# Processing Record 172 of set 1 |kodiak
# Processing Record 173 of set 1 |filadelfia
# Processing Record 174 of set 1 |thompson
# Processing Record 175 of set 1 |mount isa
# Processing Record 176 of set 1 |tumannyy
# tumannyy not found in API response.
# Processing Record 177 of set 1 |parkes
# Processing Record 178 of set 1 |waddan
# Processing Record 179 of set 1 |cabo san lucas
# Processing Record 180 of set 1 |nam tha
# nam tha not found in API response.
# Processing Record 181 of set 1 |san patricio
# Processing Record 182 of set 1 |merrill
# Processing Record 183 of set 1 |mys shmidta
# mys shmidta not found in API response.
# Processing Record 184 of set 1 |miri
# Processing Record 185 of set 1 |brokopondo
# Processing Record 186 of set 1 |lata
# Processing Record 187 of set 1 |fevralsk
# fevralsk not found in API response.
# Processing Record 188 of set 1 |fortuna
# Processing Record 189 of set 1 |mukhen
# Processing Record 190 of set 1 |victoria
# Processing Record 191 of set 1 |dawlatabad
# Processing Record 192 of set 1 |torbay
# Processing Record 193 of set 1 |altay
# Processing Record 194 of set 1 |arrecife
# Processing Record 195 of set 1 |korla
# Processing Record 196 of set 1 |palauig
# Processing Record 197 of set 1 |tillabery
# tillabery not found in API response.
# Processing Record 198 of set 1 |rondonopolis
# Processing Record 199 of set 1 |emerald
# Processing Record 200 of set 1 |antalaha
# Processing Record 201 of set 1 |padang
# Processing Record 202 of set 1 |bereda
# Processing Record 203 of set 1 |cidreira
# Processing Record 204 of set 1 |husavik
# Processing Record 205 of set 1 |lebu
# Processing Record 206 of set 1 |te anau
# Processing Record 207 of set 1 |mocuba
# Processing Record 208 of set 1 |keuruu
# Processing Record 209 of set 1 |carnarvon
# Processing Record 210 of set 1 |maragogi
# Processing Record 211 of set 1 |hovd
# Processing Record 212 of set 1 |yatou
# Processing Record 213 of set 1 |hay river
# Processing Record 214 of set 1 |nantucket
# Processing Record 215 of set 1 |paita
# Processing Record 216 of set 1 |kendari
# Processing Record 217 of set 1 |merauke
# Processing Record 218 of set 1 |oktyabrskiy
# Processing Record 219 of set 1 |atyrau
# Processing Record 220 of set 1 |longyearbyen
# Processing Record 221 of set 1 |moron
# Processing Record 222 of set 1 |myitkyina
# Processing Record 223 of set 1 |cayenne
# Processing Record 224 of set 1 |rio brilhante
# Processing Record 225 of set 1 |tiznit
# Processing Record 226 of set 1 |goderich
# Processing Record 227 of set 1 |ginda
# Processing Record 228 of set 1 |bijie
# Processing Record 229 of set 1 |tchibanga
# Processing Record 230 of set 1 |saurimo
# Processing Record 231 of set 1 |srednekolymsk
# Processing Record 232 of set 1 |kamina
# Processing Record 233 of set 1 |provideniya
# Processing Record 234 of set 1 |male
# Processing Record 235 of set 1 |turbat
# Processing Record 236 of set 1 |isiro
# Processing Record 237 of set 1 |la peca
# Processing Record 238 of set 1 |belmonte
# Processing Record 239 of set 1 |mayo
# Processing Record 240 of set 1 |coahuayana
# Processing Record 241 of set 1 |neftegorsk
# Processing Record 242 of set 1 |calarca
# Processing Record 243 of set 1 |iqaluit
# Processing Record 244 of set 1 |miraflores
# Processing Record 245 of set 1 |vihti
# Processing Record 246 of set 1 |mergui
# mergui not found in API response.
# Processing Record 247 of set 1 |kryve ozero
# Processing Record 248 of set 1 |weihe
# Processing Record 249 of set 1 |miramar
# Processing Record 250 of set 1 |hachinohe
# Processing Record 251 of set 1 |dikson
# Processing Record 252 of set 1 |grand centre
# grand centre not found in API response.
# Processing Record 253 of set 1 |caravelas
# Processing Record 254 of set 1 |mana
# Processing Record 255 of set 1 |pangoa
# Processing Record 256 of set 1 |leningradskiy
# Processing Record 257 of set 1 |pak phanang
# Processing Record 258 of set 1 |takoradi
# Processing Record 259 of set 1 |rio gallegos
# Processing Record 260 of set 1 |namatanai
# Processing Record 261 of set 1 |verkh-usugli
# Processing Record 262 of set 1 |abu kamal
# Processing Record 263 of set 1 |severnyy
# Processing Record 264 of set 1 |deputatskiy
# Processing Record 265 of set 1 |luxeuil-les-bains
# Processing Record 266 of set 1 |lakatoro
# Processing Record 267 of set 1 |weligama
# Processing Record 268 of set 1 |saint-pierre
# Processing Record 269 of set 1 |pevek
# Processing Record 270 of set 1 |pomabamba
# Processing Record 271 of set 1 |ornskoldsvik
# Processing Record 272 of set 1 |sioux lookout
# Processing Record 273 of set 1 |pinos
# Processing Record 274 of set 1 |ponta do sol
# Processing Record 275 of set 1 |porgera
# Processing Record 276 of set 1 |barentsburg
# barentsburg not found in API response.
# Processing Record 277 of set 1 |port macquarie
# Processing Record 278 of set 1 |tunceli
# Processing Record 279 of set 1 |berlevag
# Processing Record 280 of set 1 |belushya guba
# belushya guba not found in API response.
# Processing Record 281 of set 1 |aksu
# Processing Record 282 of set 1 |paracuru
# Processing Record 283 of set 1 |clarence town
# Processing Record 284 of set 1 |guerrero negro
# Processing Record 285 of set 1 |hun
# Processing Record 286 of set 1 |talnakh
# Processing Record 287 of set 1 |ambon
# Processing Record 288 of set 1 |kushima
# Processing Record 289 of set 1 |saint-michel-des-saints
# Processing Record 290 of set 1 |shelburne
# Processing Record 291 of set 1 |tsihombe
# tsihombe not found in API response.
# Processing Record 292 of set 1 |sola
# Processing Record 293 of set 1 |araouane
# Processing Record 294 of set 1 |bayan
# Processing Record 295 of set 1 |makakilo city
# Processing Record 296 of set 1 |norman wells
# Processing Record 297 of set 1 |pisco
# Processing Record 298 of set 1 |mahajanga
# Processing Record 299 of set 1 |hienghene
# Processing Record 300 of set 1 |lins
# Processing Record 301 of set 1 |tagusao
# Processing Record 302 of set 1 |dingle
# Processing Record 303 of set 1 |falun
# Processing Record 304 of set 1 |sao felix do xingu
# Processing Record 305 of set 1 |half moon bay
# Processing Record 306 of set 1 |genhe
# Processing Record 307 of set 1 |sao filipe
# Processing Record 308 of set 1 |tuatapere
# Processing Record 309 of set 1 |ilulissat
# Processing Record 310 of set 1 |synya
# Processing Record 311 of set 1 |saint george
# Processing Record 312 of set 1 |malwan
# malwan not found in API response.
# Processing Record 313 of set 1 |port-cartier
# Processing Record 314 of set 1 |petropavlovsk-kamchatskiy
# Processing Record 315 of set 1 |wanlaweyn
# Processing Record 316 of set 1 |fairlie
# Processing Record 317 of set 1 |neringa
# Processing Record 318 of set 1 |mbandaka
# Processing Record 319 of set 1 |meulaboh
# Processing Record 320 of set 1 |banda aceh
# Processing Record 321 of set 1 |aksarka
# Processing Record 322 of set 1 |trapani
# Processing Record 323 of set 1 |tessalit
# Processing Record 324 of set 1 |sitka
# Processing Record 325 of set 1 |bose
# Processing Record 326 of set 1 |saskylakh
# Processing Record 327 of set 1 |olafsvik
# Processing Record 328 of set 1 |llanes
# Processing Record 329 of set 1 |gwadar
# Processing Record 330 of set 1 |jardim
# Processing Record 331 of set 1 |muros
# Processing Record 332 of set 1 |bethel
# Processing Record 333 of set 1 |sungaipenuh
# Processing Record 334 of set 1 |santa rosa
# Processing Record 335 of set 1 |barabinsk
# Processing Record 336 of set 1 |sentyabrskiy
# sentyabrskiy not found in API response.
# Processing Record 337 of set 1 |talcahuano
# Processing Record 338 of set 1 |warqla
# warqla not found in API response.
# Processing Record 339 of set 1 |tyulyachi
# Processing Record 340 of set 1 |bemidji
# Processing Record 341 of set 1 |soyaux
# Processing Record 342 of set 1 |iroquois falls
# Processing Record 343 of set 1 |bisira
# Processing Record 344 of set 1 |dakar
# Processing Record 345 of set 1 |le port
# Processing Record 346 of set 1 |guadalupe y calvo
# Processing Record 347 of set 1 |misratah
# Processing Record 348 of set 1 |zhenlai
# Processing Record 349 of set 1 |rovenki
# Processing Record 350 of set 1 |sinnamary
# Processing Record 351 of set 1 |tevaitoa
# Processing Record 352 of set 1 |griffin
# Processing Record 353 of set 1 |george
# Processing Record 354 of set 1 |yulara
# Processing Record 355 of set 1 |giresun
# Processing Record 356 of set 1 |yagodnoye
# Processing Record 357 of set 1 |mazagao
# Processing Record 358 of set 1 |kiruna
# Processing Record 359 of set 1 |sicamous
# Processing Record 360 of set 1 |french harbor
# Processing Record 361 of set 1 |waw
# Processing Record 362 of set 1 |middelburg
# Processing Record 363 of set 1 |tenenkou
# Processing Record 364 of set 1 |noumea
# Processing Record 365 of set 1 |kurush
# Processing Record 366 of set 1 |kelo
# Processing Record 367 of set 1 |ust-kamchatsk
# ust-kamchatsk not found in API response.
# Processing Record 368 of set 1 |khorramshahr
# Processing Record 369 of set 1 |yeniseysk
# Processing Record 370 of set 1 |saint-leu
# Processing Record 371 of set 1 |wielun
# Processing Record 372 of set 1 |waingapu
# Processing Record 373 of set 1 |amderma
# amderma not found in API response.
# Processing Record 374 of set 1 |savonlinna
# Processing Record 375 of set 1 |ipixuna
# Processing Record 376 of set 1 |shaki
# Processing Record 377 of set 1 |matara
# Processing Record 378 of set 1 |fort nelson
# Processing Record 379 of set 1 |amazar
# Processing Record 380 of set 1 |nishihara
# Processing Record 381 of set 1 |xacmaz
# Processing Record 382 of set 1 |aysha
# Processing Record 383 of set 1 |pacific grove
# Processing Record 384 of set 1 |sistranda
# Processing Record 385 of set 1 |clyde river
# Processing Record 386 of set 1 |otane
# Processing Record 387 of set 1 |tambun
# Processing Record 388 of set 1 |agdam
# Processing Record 389 of set 1 |zhenhai
# Processing Record 390 of set 1 |pangnirtung
# Processing Record 391 of set 1 |khani
# Processing Record 392 of set 1 |khandyga
# Processing Record 393 of set 1 |faya
# Processing Record 394 of set 1 |jiujiang
# Processing Record 395 of set 1 |vidim
# Processing Record 396 of set 1 |mokolo
# Processing Record 397 of set 1 |lima
# Processing Record 398 of set 1 |lagoa
# Processing Record 399 of set 1 |hernani
# Processing Record 400 of set 1 |mauswagon
# mauswagon not found in API response.
# Processing Record 401 of set 1 |moji-mirim
# moji-mirim not found in API response.
# Processing Record 402 of set 1 |coquimbo
# Processing Record 403 of set 1 |avera
# Processing Record 404 of set 1 |pimentel
# Processing Record 405 of set 1 |buala
# Processing Record 406 of set 1 |paso de los toros
# Processing Record 407 of set 1 |mananara
# Processing Record 408 of set 1 |kudahuvadhoo
# Processing Record 409 of set 1 |huarmey
# Processing Record 410 of set 1 |margate
# Processing Record 411 of set 1 |longyan
# Processing Record 412 of set 1 |hvammstangi
# hvammstangi not found in API response.
# Processing Record 413 of set 1 |itarema
# Processing Record 414 of set 1 |tual
# Processing Record 415 of set 1 |salekhard
# Processing Record 416 of set 1 |dunedin
# Processing Record 417 of set 1 |mount gambier
# Processing Record 418 of set 1 |sosua
# Processing Record 419 of set 1 |cruzeiro do sul
# Processing Record 420 of set 1 |egvekinot
# Processing Record 421 of set 1 |komsomolskiy
# Processing Record 422 of set 1 |nemuro
# Processing Record 423 of set 1 |omsukchan
# Processing Record 424 of set 1 |grindavik
# Processing Record 425 of set 1 |novyy buyan
# Processing Record 426 of set 1 |vanimo
# Processing Record 427 of set 1 |doctor arroyo
# Processing Record 428 of set 1 |den helder
# Processing Record 429 of set 1 |samalaeulu
# samalaeulu not found in API response.
# Processing Record 430 of set 1 |nelson bay
# Processing Record 431 of set 1 |abu samrah
# Processing Record 432 of set 1 |salym
# Processing Record 433 of set 1 |laguna
# Processing Record 434 of set 1 |villamontes
# Processing Record 435 of set 1 |korampallam
# Processing Record 436 of set 1 |oranjemund
# Processing Record 437 of set 1 |umm lajj
# Processing Record 438 of set 1 |mortka
# Processing Record 439 of set 1 |abu jubayhah
# abu jubayhah not found in API response.
# Processing Record 440 of set 1 |ksenyevka
# ksenyevka not found in API response.
# Processing Record 441 of set 1 |adeje
# Processing Record 442 of set 1 |bengkulu
# Processing Record 443 of set 1 |manggar
# Processing Record 444 of set 1 |omboue
# Processing Record 445 of set 1 |nadym
# Processing Record 446 of set 1 |kiliya
# Processing Record 447 of set 1 |lithakia
# Processing Record 448 of set 1 |bubaque
# Processing Record 449 of set 1 |rome
# Processing Record 450 of set 1 |rajmahal
# Processing Record 451 of set 1 |porbandar
# Processing Record 452 of set 1 |othaya
# Processing Record 453 of set 1 |dangara
# Processing Record 454 of set 1 |henties bay
# Processing Record 455 of set 1 |la rioja
# Processing Record 456 of set 1 |kavaratti
# Processing Record 457 of set 1 |riyadh
# Processing Record 458 of set 1 |arawa
# Processing Record 459 of set 1 |tautira
# Processing Record 460 of set 1 |rawdon
# Processing Record 461 of set 1 |kropotkin
# Processing Record 462 of set 1 |freeport
# Processing Record 463 of set 1 |manlleu
# Processing Record 464 of set 1 |kavieng
# Processing Record 465 of set 1 |abha
# Processing Record 466 of set 1 |gat
# Processing Record 467 of set 1 |kruisfontein
# Processing Record 468 of set 1 |kuhestan
# kuhestan not found in API response.
# Processing Record 469 of set 1 |tyup
# Processing Record 470 of set 1 |terney
# Processing Record 471 of set 1 |eregli
# Processing Record 472 of set 1 |kobayashi
# Processing Record 473 of set 1 |solnechnyy
# Processing Record 474 of set 1 |ketchikan
# Processing Record 475 of set 1 |calabozo
# Processing Record 476 of set 1 |ullapool
# Processing Record 477 of set 1 |praia
# Processing Record 478 of set 1 |harrismith
# Processing Record 479 of set 1 |khonsa
# Processing Record 480 of set 1 |hukuntsi
# Processing Record 481 of set 1 |mount darwin
# Processing Record 482 of set 1 |charters towers
# Processing Record 483 of set 1 |edd
# Processing Record 484 of set 1 |puerto baquerizo moreno
# Processing Record 485 of set 1 |zhigansk
# Processing Record 486 of set 1 |beirut
# Processing Record 487 of set 1 |kologriv
# Processing Record 488 of set 1 |sirvintos
# Processing Record 489 of set 1 |anna paulowna
# Processing Record 490 of set 1 |saldanha
# Processing Record 491 of set 1 |pontianak
# Processing Record 492 of set 1 |balabac
# Processing Record 493 of set 1 |bakchar
# Processing Record 494 of set 1 |linchuan
# linchuan not found in API response.
# Processing Record 495 of set 1 |miyang
# Processing Record 496 of set 1 |atar
# Processing Record 497 of set 1 |trinidad
# Processing Record 498 of set 1 |krasnoselkup
# Processing Record 499 of set 1 |kurchum
# Processing Record 500 of set 1 |ust-maya
# Processing Record 501 of set 1 |yerofey pavlovich
# Processing Record 502 of set 1 |vila do maio
# Processing Record 503 of set 1 |xam nua
# Processing Record 504 of set 1 |lolua
# lolua not found in API response.
# Processing Record 505 of set 1 |scarborough
# Processing Record 506 of set 1 |vestmanna
# Processing Record 507 of set 1 |uthal
# Processing Record 508 of set 1 |susurluk
# Processing Record 509 of set 1 |peyima
# Processing Record 510 of set 1 |havre-saint-pierre
# Processing Record 511 of set 1 |sandakan
# Processing Record 512 of set 1 |saint anthony
# Processing Record 513 of set 1 |acoua
# Processing Record 514 of set 1 |tselinnoye
# Processing Record 515 of set 1 |vardo
# Processing Record 516 of set 1 |mareeba
# Processing Record 517 of set 1 |karoi
# Processing Record 518 of set 1 |maghama
# maghama not found in API response.
# Processing Record 519 of set 1 |phan thiet
# Processing Record 520 of set 1 |marawi
# Processing Record 521 of set 1 |sabla
# Processing Record 522 of set 1 |naftah
# naftah not found in API response.
# Processing Record 523 of set 1 |cap-aux-meules
# Processing Record 524 of set 1 |saryg-sep
# Processing Record 525 of set 1 |bhopal
# Processing Record 526 of set 1 |north battleford
# Processing Record 527 of set 1 |celestun
# Processing Record 528 of set 1 |machinga
# Processing Record 529 of set 1 |harper
# Processing Record 530 of set 1 |yining
# Processing Record 531 of set 1 |bud
# Processing Record 532 of set 1 |puksoozero
# Processing Record 533 of set 1 |ozernovskiy
# Processing Record 534 of set 1 |monrovia
# Processing Record 535 of set 1 |rioja
# Processing Record 536 of set 1 |port arthur
# Processing Record 537 of set 1 |pingxiang
# Processing Record 538 of set 1 |dolgoderevenskoye
# Processing Record 539 of set 1 |ixtapa
# Processing Record 540 of set 1 |mataram
# Processing Record 541 of set 1 |hambantota
# Processing Record 542 of set 1 |yakeshi
# Processing Record 543 of set 1 |treinta y tres
# Processing Record 544 of set 1 |bejar
# Processing Record 545 of set 1 |vakhtan
# Processing Record 546 of set 1 |dauriya
# Processing Record 547 of set 1 |sabang
# Processing Record 548 of set 1 |tignere
# Processing Record 549 of set 1 |coihaique
# Processing Record 550 of set 1 |pokosnoye
# Processing Record 551 of set 1 |excelsior springs
# Processing Record 552 of set 1 |ouagadougou
# Processing Record 553 of set 1 |pompeu
# Processing Record 554 of set 1 |rincon
# Processing Record 555 of set 1 |rawson
# Processing Record 556 of set 1 |ellensburg
# Processing Record 557 of set 1 |ponnani
# Processing Record 558 of set 1 |manavalakurichi
# Processing Record 559 of set 1 |kimbe
# Processing Record 560 of set 1 |pundaguitan
# Processing Record 561 of set 1 |ajdabiya
# Processing Record 562 of set 1 |maningrida
# Processing Record 563 of set 1 |hami
# Processing Record 564 of set 1 |sonepur
# Processing Record 565 of set 1 |asau
# Processing Record 566 of set 1 |viedma
# Processing Record 567 of set 1 |cochrane
# Processing Record 568 of set 1 |khabary
# Processing Record 569 of set 1 |luena
# Processing Record 570 of set 1 |ndele
# Processing Record 571 of set 1 |kawalu
# Processing Record 572 of set 1 |gonbad-e qabus
# Processing Record 573 of set 1 |santiago del estero
# Processing Record 574 of set 1 |borlange
# borlange not found in API response.
# Processing Record 575 of set 1 |tarakan
# Processing Record 576 of set 1 |fairbanks
# Processing Record 577 of set 1 |shache
# Processing Record 578 of set 1 |sjenica
# Processing Record 579 of set 1 |miracema do tocantins
# Processing Record 580 of set 1 |mehamn
# Processing Record 581 of set 1 |buritis
# Processing Record 582 of set 1 |jiwani
# Processing Record 583 of set 1 |conceicao do araguaia
# Processing Record 584 of set 1 |caibarien
# Processing Record 585 of set 1 |inongo
# Processing Record 586 of set 1 |roma
# Processing Record 587 of set 1 |nome
# Processing Record 588 of set 1 |ishigaki
# Processing Record 589 of set 1 |remedios
# Processing Record 590 of set 1 |kon tum
# Processing Record 591 of set 1 |port-gentil
# Processing Record 592 of set 1 |veraval
# Processing Record 593 of set 1 |manakara
# Processing Record 594 of set 1 |gomel
# Processing Record 595 of set 1 |phan rang
# phan rang not found in API response.
# Processing Record 596 of set 1 |sembe
# Processing Record 597 of set 1 |jiroft
# jiroft not found in API response.
# Processing Record 598 of set 1 |tura
# Processing Record 599 of set 1 |brae
# Processing Record 600 of set 1 |khonuu
# khonuu not found in API response.
# Processing Record 601 of set 1 |acari
# Processing Record 602 of set 1 |jaguaribe
# Processing Record 603 of set 1 |sahuaripa
# Processing Record 604 of set 1 |el prat de llobregat
# Processing Record 605 of set 1 |sijunjung
# Processing Record 606 of set 1 |astana
# Processing Record 607 of set 1 |karaidel
# Processing Record 608 of set 1 |rio grande
# Processing Record 609 of set 1 |malindi
# Processing Record 610 of set 1 |kaifeng
# Processing Record 611 of set 1 |malakal
# Processing Record 612 of set 1 |calvinia
# Processing Record 613 of set 1 |maltahohe
# Processing Record 614 of set 1 |kirksville
# Processing Record 615 of set 1 |ormara
# Processing Record 616 of set 1 |bintulu
# Processing Record 617 of set 1 |cilegon
# Processing Record 618 of set 1 |lalomanu
# lalomanu not found in API response.
# Processing Record 619 of set 1 |slave lake
# Processing Record 620 of set 1 |sechura
# Processing Record 621 of set 1 |khash
# Processing Record 622 of set 1 |toliary
# toliary not found in API response.
# Processing Record 623 of set 1 |hervey bay
# Processing Record 624 of set 1 |sisimiut
# Processing Record 625 of set 1 |poum
# Processing Record 626 of set 1 |pochutla
# Processing Record 627 of set 1 |chengmai
# chengmai not found in API response.
# Processing Record 628 of set 1 |iranshahr
# Processing Record 629 of set 1 |keetmanshoop
# Processing Record 630 of set 1 |bowen

# %%
north_lat = [] # establishes northern and southern hemisphere values to plot
north_t = []
north_h = []
north_c = []
north_ws = []
south_lat = []
south_t = []
south_h = []
south_c = []
south_ws = []
for x in range(len(mod_lngs)):
    if mod_lngs[x] > 0:
        north_lat.append(mod_lat[x])
        north_t.append(MaxtempF[x])
        north_h.append(humidityperc[x])
        north_c.append(cloudiness[x])
        north_ws.append(windmph[x])
        x += 1
    else:
        south_lat.append(mod_lat[x])
        south_t.append(MaxtempF[x])
        south_h.append(humidityperc[x])
        south_c.append(cloudiness[x])
        south_ws.append(windmph[x])
        x += 1

# %%
#Export the city data into a .csv.
os.getcwd()
# Out:
# '/Users/tonypalazzolo/API-JSON-Challenge-II'

# %%
#Display the DataFrame
weather_df = pd.DataFrame({"city": mod_cities,
                           "country": country,
                            "longitude": mod_lngs,
                            "latitude": mod_lat,
                           "Temperature F": MaxtempF,
                           "Humidity %":humidityperc,
                           "Cloudiness": cloudiness,
                           "Wind Speed mph": windmph})
weather_df.to_csv('cities.csv', index=False, header=True)
weather_df
# Out:
#              city country  longitude  latitude  Temperature F  Humidity %  \
# 0       Busselton      AU     115.33    -33.65          66.00          69
# 1    Port Lincoln      AU     135.87    -34.73          56.48          73
# 2          Sorong      ID     131.25     -0.88          82.74          78
# 3     San Quintín      MX    -115.95     30.48          61.70          49
# 4       Jamestown      US     -79.24     42.10          34.00          94
# ..            ...     ...        ...       ...            ...         ...
# 577          Poum      NC     164.02    -20.23          78.73          77
# 578      Pochutla      MX     -96.47     15.74          84.99          61
# 579     Iranshahr      IR      60.68     27.20          62.60          34
# 580  Keetmanshoop      NA      18.13    -26.58          88.68          24
# 581         Bowen      AU     148.23    -20.02          77.00          88
#
#      Cloudiness  Wind Speed mph
# 0         10000            1.99
# 1         10000            9.10
# 2         10000           11.65
# 3         10000            4.25
# 4          3219           14.65
# ..          ...             ...
# 577       10000            6.17
# 578        9656            2.17
# 579       10000            6.93
# 580       10000           17.16
# 581       10000            4.70
#
# [582 rows x 8 columns]

# %%
weather_df.describe()
# Out:
#        longitude    latitude  Temperature F  Humidity %    Cloudiness  \
# count  582.00000  582.000000     582.000000  582.000000    582.000000
# mean    22.29988   19.361564      52.750911   73.393471   8965.943299
# std     89.24024   33.072179      31.560591   19.781113   2595.469891
# min   -179.17000  -54.800000     -45.900000   10.000000     89.000000
# 25%    -54.23750   -8.417500      34.000000   65.000000  10000.000000
# 50%     27.95500   22.705000      62.600000   78.500000  10000.000000
# 75%    100.30500   47.355000      78.172500   88.000000  10000.000000
# max    178.42000   78.220000      97.200000  100.000000  10000.000000
#
#        Wind Speed mph
# count      582.000000
# mean         7.968591
# std          6.134930
# min          0.110000
# 25%          3.602500
# 50%          6.710000
# 75%         10.290000
# max         53.020000

# %%
weather_df.columns
weather_df["Humidity %"].max()
#no cities display greater than 100% humidity
# Out:
# 100

# %%
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#Save the plotted figures as .pngs.
        # northern hemisphere has positive longitude, southern has negative

plt.scatter(mod_lat, MaxtempF, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude by Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("city_max_temp.png")
plt.show()
##Analysis- there seems to be a generally negative correlation; temperature decreases as latitude increases.
#           max temps occur at latitudes between ~-30 to 10 degrees in latitude

# %%
plt.scatter(mod_lat,humidityperc, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude by Percent Humidity")
plt.xlabel("Latitude")
plt.ylabel("Percent Humidity")
plt.savefig("city_humidity.png")
plt.show()
## ANALYSIS - there seems to be no correlation between city by latitude and humidity. It seems fairly distributed
#             accross locations, regardless of area.

# %%
plt.scatter( mod_lat,cloudiness, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude by Cloudiness(Visibility)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("city_cloudiness.png")
plt.show()
## ANALYSIS - cloudiness (visibility) seems to slightly skew negatively for higher latitudes
#.            althought a slight negative correlation, cloudiness remains fairly consistens in magnitude accross 
#.             cities.

# %%
plt.scatter(mod_lat,windmph, marker="o", facecolors="red", edgecolors="black")
plt.title("City Latitude by Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)") 
plt.savefig("city_wind_speed.png")
plt.show()
## ANALYSIS - There is no apparent trent in data for city and wind speed; not much data apparent 
#.            for wind speeds greater than 30 mph

# %%
#Northern Hemisphere - Temperature (F) vs. Latitude (long > 0)
north_lat_series = pd.Series(north_lat)
slopent, interceptnt, rvaluent, pvaluent, stderrnt = linregress(north_lat, north_t)
rnt = north_lat_series * slopent + interceptnt
line_eq_nt = "y = " + str(round(slopent,2)) + "x + " + str(round(interceptnt,2))
plt.scatter(north_lat,north_t, marker="o", facecolors="red", edgecolors="black")
plt.plot(north_lat,rnt,"r-")
plt.title("Temperature(F) vs. Latitude in Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Temperature(F)") 
plt.savefig("city_tempvs_lat_n.png")
plt.show()
print( "r value for temp vs. latitude(N) is " + str(rvaluent))
print("Northern " + line_eq_nt)
##ANALYSIS
print("As predicted, there is a fairly strong negative trend for temperatures by latitude, indicated by r= " + str(rvaluent) + "." )


#Southern Hemisphere - Temperature (F) vs. Latitude (long < 0)
south_lat_series = pd.Series(south_lat)
slopest, interceptst, rvaluest, pvaluest, stderrst = linregress(south_lat, south_t)
rst = south_lat_series * slopest + interceptst
line_eq_st = "y = " + str(round(slopest,2)) + "x + " + str(round(interceptst,2))
plt.scatter(south_lat,south_t, marker="o", facecolors="red", edgecolors="black")
plt.plot(south_lat,rst,"r-")
plt.title("Temperature(F) vs. Latitude in Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Temperature(F)")
plt.savefig("city_tempvs_lat_s.png")
plt.show()
print( "Southern r value for temp vs latitude(S) " + str(rvaluest))
print(line_eq_st)
# ANALYSIS
print("As predicted, there is a fairly strong negative trend for temperatures by latitude, indicated by r= " + str(rvaluest) + "." )
print("This does not seem to change significantly between Northern and Southern Hemispheres.")
# Out:
# r value for temp vs. latitude(N) is -0.7641735833786841
# Northern y = -0.77x + 64.59
# As predicted, there is a fairly strong negative trend for temperatures by latitude, indicated by r= -0.7641735833786841.
# Southern r value for temp vs latitude(S) -0.7752312034356971
# y = -0.66x + 70.32
# As predicted, there is a fairly strong negative trend for temperatures by latitude, indicated by r= -0.7752312034356971.
# This does not seem to change significantly between Northern and Southern Hemispheres.

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude

slopenh, interceptnh, rvaluenh, pvaluenh, stderrnh = linregress(north_lat, north_h)
rnh = north_lat_series * slopenh + interceptnh
line_eq_nh = "y = " + str(round(slopenh,2)) + "x + " + str(round(interceptnh,2))
plt.scatter(north_lat,north_h, marker="o", facecolors="red", edgecolors="black")
plt.plot(north_lat,rnh,"r-")
plt.title("Percent Humidity vs. Latitude in Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Humidity %") 
plt.savefig("city_humvs_lat_n.png")
plt.show()
print( "r value for temp vs. Humidity(N) is " + str(rvaluenh))
print("Northern " + line_eq_nh)
# ANALYSIS
print("Relative to Southern Hemisphere, there is a slight posistive trend for humidity by latitude, according to the")
print ("r-value.")

#Southern Hemisphere - Humidity (%) vs. Latitude

slopesh, interceptsh, rvaluesh, pvaluesh, stderrsh = linregress(south_lat, south_h)
rsh = south_lat_series * slopesh + interceptsh
line_eq_sh = "y = " + str(round(slopesh,2)) + "x + " + str(round(interceptsh,2))
plt.plot(south_lat,rsh,"r-")
plt.scatter(south_lat,south_h, marker="o", facecolors="red", edgecolors="black")
plt.title("Percent Humidity vs. Latitude in Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.savefig("city_humvs_lat_s.png")
plt.show()
print( "r value for temp vs. Humidity(S) is " + str(rvaluesh))
print("Southern " + line_eq_sh)
# Analysis
print("there is about zero correlation in data for the Southern Hemisphere by percent humidiy")
# Out:
# r value for temp vs. Humidity(N) is 0.19359308938112416
# Northern y = 0.11x + 75.24
# Relative to Southern Hemisphere, there is a slight posistive trend for humidity by latitude, according to the
# r-value.
# r value for temp vs. Humidity(S) is 0.4337647474546732
# Southern y = 0.28x + 61.76
# there is about zero correlation in data for the Southern Hemisphere by percent humidiy

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude
slopenc, interceptnc, rvaluenc, pvaluenc, stderrnc = linregress(north_lat, north_c)
rnc = north_lat_series * slopenc + interceptnc
line_eq_nc = "y = " + str(round(slopenc,2)) + "x + " + str(round(interceptnc,2))
plt.plot(north_lat,rnc,"r-")
plt.scatter(north_lat,north_c, marker="o", facecolors="red", edgecolors="black")
plt.title("Cloudiness (Visibility) vs. Latitude in Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Visibility") 
plt.savefig("city_clvs_lat_n.png")
plt.show()
print( "r value for temp vs. cloudiness (N) is " + str(rvaluenc))
print("Northern " + line_eq_nc)
#Southern Hemisphere - Cloudiness (%) vs. Latitude
slopesc, interceptsc, rvaluesc, pvaluesc, stderrsc = linregress(south_lat, south_c)
rsc = south_lat_series * slopesc + interceptsc
line_eq_sc = "y = " + str(round(slopesc,2)) + "x + " + str(round(interceptsc,2))
plt.plot(south_lat,rsc,"r-")
plt.scatter(south_lat, south_c, marker="o", facecolors="red", edgecolors="black")
plt.title("Cloudiness(Visibility) vs. Latitude in Southern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Visibility")
plt.savefig("city_clvs_lat_s.png")
plt.show()
print( "r value for temp vs. cloudiness(S) is " + str(rvaluesc))
print("Southern " + line_eq_sc)
# ANALYSIS
print("There appears a consistent, slightly negative trend for both Hemispheres regarding cloudiness data by latitude")
# Out:
# r value for temp vs. cloudiness (N) is -0.318869249690197
# Northern y = -22.5x + 9421.88
# r value for temp vs. cloudiness(S) is -0.28367348533285325
# Southern y = -14.9x + 9850.99

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
slopenws, interceptnws, rvaluenws, pvaluenws, stderrnws = linregress(north_lat, north_ws)
rnws = north_lat_series * slopenws + interceptnws
line_eq_nws = "y = " + str(round(slopenws,2)) + "x + " + str(round(interceptnws,2))
plt.plot(north_lat,rnws,"r-")
plt.scatter(north_lat,north_ws, marker="o", facecolors="red", edgecolors="black")
plt.title("Wind Speed vs. Latitude in Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.savefig("city_wsvs_lat_n.png")
plt.show()
print( "r value for temp vs. wind speed (N) is " + str(rvaluenws))
print("Northern " + line_eq_nws)

# ANALYSIS
print("There is a slight negative correlation of wind speed by city for the Northern Hemisphere")
#Southern Hemisphere - Wind Speed (mph) vs. Latitude

slopesws, interceptsws, rvaluesws, pvaluesws, stderrsws = linregress(south_lat, south_ws)
rsws = south_lat_series * slopesws + interceptsws
line_eq_sws = "y = " + str(round(slopesws,2)) + "x + " + str(round(interceptsws,2))
plt.plot(south_lat,rsws,"r-")
plt.scatter(south_lat,south_ws, marker="o", facecolors="red", edgecolors="black")
plt.title("Wind Speed vs. Latitude in Northern Hemisphere")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.savefig("city_wsvs_lat_s.png")
plt.show()
print( "r value for temp vs. wind speed (S) is " + str(rvaluesws))
print("Southern " + line_eq_sws)
# Analysis
print("Opposed to the Northern Hemisphere, there is a slight positive correlation of wind speed by city; it is ")
print("unknown if these disparities in relationship for wind speed is statistically significant")
# Out:
# r value for temp vs. wind speed (N) is 0.014523429629515706
# Northern y = 0.0x + 7.15
# There is a slight negative correlation of wind speed by city for the Northern Hemisphere
# r value for temp vs. wind speed (S) is 0.1290223267547975
# Southern y = 0.03x + 8.7
# Opposed to the Northern Hemisphere, there is a slight positive correlation of wind speed by city; it is
# unknown if these disparities in relationship for wind speed is statistically significant
